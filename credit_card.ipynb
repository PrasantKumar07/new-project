# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv(r'c:\Users\HP\Downloads\credit card.csv')

# %%
df
# Out:
#       step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0        1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1        1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2        1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3        1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4        1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# ...    ...       ...       ...          ...            ...             ...
# 3137    95  CASH_OUT  56745.14   C526144262       56745.14            0.00
# 3138    95  TRANSFER  33676.59   C732111322       33676.59            0.00
# 3139    95  CASH_OUT  33676.59  C1000086512       33676.59            0.00
# 3140    95  TRANSFER  87999.25   C927181710       87999.25            0.00
# 3141    95  CASH_OUT  87999.25   C409531429       87999.25            0.00
#
#          nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0     M1979787155            0.00            0.00        0               0
# 1     M2044282225            0.00            0.00        0               0
# 2      C553264065            0.00            0.00        1               0
# 3       C38997010        21182.00            0.00        1               0
# 4     M1230701703            0.00            0.00        0               0
# ...           ...             ...             ...      ...             ...
# 3137    C79051264        51433.88       108179.02        1               0
# 3138  C1140210295            0.00            0.00        1               0
# 3139  C1759363094            0.00        33676.59        1               0
# 3140   C757947873            0.00            0.00        1               0
# 3141  C1827219533            0.00        87999.25        1               0
#
# [3142 rows x 11 columns]

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.tail()
# Out:
#       step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 3137    95  CASH_OUT  56745.14   C526144262       56745.14             0.0
# 3138    95  TRANSFER  33676.59   C732111322       33676.59             0.0
# 3139    95  CASH_OUT  33676.59  C1000086512       33676.59             0.0
# 3140    95  TRANSFER  87999.25   C927181710       87999.25             0.0
# 3141    95  CASH_OUT  87999.25   C409531429       87999.25             0.0
#
#          nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 3137    C79051264        51433.88       108179.02        1               0
# 3138  C1140210295            0.00            0.00        1               0
# 3139  C1759363094            0.00        33676.59        1               0
# 3140   C757947873            0.00            0.00        1               0
# 3141  C1827219533            0.00        87999.25        1               0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3142 entries, 0 to 3141
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   step            3142 non-null   int64
#  1   type            3142 non-null   object
#  2   amount          3142 non-null   float64
#  3   nameOrig        3142 non-null   object
#  4   oldbalanceOrg   3142 non-null   float64
#  5   newbalanceOrig  3142 non-null   float64
#  6   nameDest        3142 non-null   object
#  7   oldbalanceDest  3142 non-null   float64
#  8   newbalanceDest  3142 non-null   float64
#  9   isFraud         3142 non-null   int64
#  10  isFlaggedFraud  3142 non-null   int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 270.1+ KB

# %%
print("Dataset shape:", df.shape)
print("\nColumns:", df.columns.tolist())
# Out:
# Dataset shape: (3142, 11)
#
# Columns: ['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig', 'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud', 'isFlaggedFraud']

# %%
# 3. Summary statistics
print(df.describe())# Transpose for better readability
# Out:
#               step        amount  oldbalanceOrg  newbalanceOrig  \
# count  3142.000000  3.142000e+03   3.142000e+03    3.142000e+03
# mean     18.181731  5.041753e+05   9.380078e+05    5.166342e+05
# std      27.917929  1.345891e+06   2.066634e+06    1.657465e+06
# min       1.000000  8.730000e+00   0.000000e+00    0.000000e+00
# 25%       1.000000  6.527698e+03   4.255750e+03    0.000000e+00
# 50%       1.000000  6.116901e+04   5.075200e+04    0.000000e+00
# 75%      33.000000  3.240747e+05   5.679323e+05    2.621973e+04
# max      95.000000  1.000000e+07   1.990000e+07    1.020000e+07
#
#        oldbalanceDest  newbalanceDest      isFraud  isFlaggedFraud
# count    3.142000e+03    3.142000e+03  3142.000000          3142.0
# mean     6.034502e+05    1.038512e+06     0.367919             0.0
# std      1.973508e+06    2.815902e+06     0.482316             0.0
# min      0.000000e+00    0.000000e+00     0.000000             0.0
# 25%      0.000000e+00    0.000000e+00     0.000000             0.0
# 50%      0.000000e+00    0.000000e+00     0.000000             0.0
# 75%      2.697847e+05    6.380216e+05     1.000000             0.0
# max      3.300000e+07    3.460000e+07     1.000000             0.0

# %%
print(df.isnull().sum())
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
# 5. Target variable distribution
print(df["isFraud"].value_counts())
# Out:
# isFraud
# 0    1986
# 1    1156
# Name: count, dtype: int64

# %%
print(df["isFraud"].value_counts(normalize=True)*100)
# Out:
# isFraud
# 0    63.208148
# 1    36.791852
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="isFraud", data=df)
plt.title("Fraud vs Non-Fraud")
plt.show()

# %%
# 6. Transaction type distribution
print(df["type"].value_counts())
# Out:
# type
# PAYMENT     998
# CASH_OUT    926
# TRANSFER    791
# CASH_IN     311
# DEBIT       116
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="type", data=df, order=df["type"].value_counts().index)
plt.title("Transaction Types")
plt.show()

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(x="type", data=df, order=df["type"].value_counts().index)

total = len(df)
for container in ax.containers:
    ax.bar_label(container, labels=[f"{(v/total*100):.1f}%" for v in container.datavalues])

plt.title("Transaction Types (Percentage)")
plt.show()

# %%
pip install mplcursors
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mplcursors
#   Downloading mplcursors-0.7-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: matplotlib!=3.10.3,!=3.7.1,>=3.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mplcursors) (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib!=3.10.3,!=3.7.1,>=3.1->mplcursors) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib!=3.10.3,!=3.7.1,>=3.1->mplcursors) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib!=3.10.3,!=3.7.1,>=3.1->mplcursors) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib!=3.10.3,!=3.7.1,>=3.1->mplcursors) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib!=3.10.3,!=3.7.1,>=3.1->mplcursors) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib!=3.10.3,!=3.7.1,>=3.1->mplcursors) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib!=3.10.3,!=3.7.1,>=3.1->mplcursors) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib!=3.10.3,!=3.7.1,>=3.1->mplcursors) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib!=3.10.3,!=3.7.1,>=3.1->mplcursors) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.10.3,!=3.7.1,>=3.1->mplcursors) (1.17.0)
# Downloading mplcursors-0.7-py3-none-any.whl (20 kB)
# Installing collected packages: mplcursors
# Successfully installed mplcursors-0.7
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 7. Amount distribution
plt.figure(figsize=(6,4))
sns.histplot(df["amount"], bins=100, kde=False)
plt.yscale("log")
plt.title("Transaction Amounts (Log scale on Y)")
plt.show()

# %%
df.plot(kind='box',subplots=True,sharey =False,figsize = (10,6))
plt.subplots_adjust(wspace=0.75)
plt.show()

# %%
# !pip install feature_engine
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: feature_engine in c:\users\hp\appdata\roaming\python\python313\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\hp\appdata\roaming\python\python313\site-packages (from feature_engine) (2.3.2)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from feature_engine) (2.3.1)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from feature_engine) (1.7.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from feature_engine) (1.16.1)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from feature_engine) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pandas>=2.2.0->feature_engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pandas>=2.2.0->feature_engine) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pandas>=2.2.0->feature_engine) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->feature_engine) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.4.0->feature_engine) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.4.0->feature_engine) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\hp\appdata\roaming\python\python313\site-packages (from statsmodels>=0.11.1->feature_engine) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\hp\appdata\roaming\python\python313\site-packages (from statsmodels>=0.11.1->feature_engine) (25.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df
# Out:
#       step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0        1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1        1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2        1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3        1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4        1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# ...    ...       ...       ...          ...            ...             ...
# 3137    95  CASH_OUT  56745.14   C526144262       56745.14            0.00
# 3138    95  TRANSFER  33676.59   C732111322       33676.59            0.00
# 3139    95  CASH_OUT  33676.59  C1000086512       33676.59            0.00
# 3140    95  TRANSFER  87999.25   C927181710       87999.25            0.00
# 3141    95  CASH_OUT  87999.25   C409531429       87999.25            0.00
#
#          nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0     M1979787155            0.00            0.00        0               0
# 1     M2044282225            0.00            0.00        0               0
# 2      C553264065            0.00            0.00        1               0
# 3       C38997010        21182.00            0.00        1               0
# 4     M1230701703            0.00            0.00        0               0
# ...           ...             ...             ...      ...             ...
# 3137    C79051264        51433.88       108179.02        1               0
# 3138  C1140210295            0.00            0.00        1               0
# 3139  C1759363094            0.00        33676.59        1               0
# 3140   C757947873            0.00            0.00        1               0
# 3141  C1827219533            0.00        87999.25        1               0
#
# [3142 rows x 11 columns]

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df["amount"])
plt.title("Boxplot of Amounts")
plt.show()

# %%
#Correlation matrix
num_cols = df.select_dtypes(include=[np.number]).columns
plt.figure(figsize=(10,8))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Fraud rate by transaction type
if "isFraud" in df.columns and "type" in df.columns:
    fraud_by_type = df.groupby("type")["isFraud"].mean().sort_values(ascending=False)
    print(fraud_by_type)

    plt.figure(figsize=(6,4))
    fraud_by_type.plot(kind="bar")
    plt.title("Fraud Rate by Transaction Type")
    plt.show()
# Out:
# type
# TRANSFER    0.720607
# CASH_OUT    0.632829
# CASH_IN     0.000000
# DEBIT       0.000000
# PAYMENT     0.000000
# Name: isFraud, dtype: float64

# %%
print("\n--- Correlation Analysis ---")
# Calculate the correlation matrix for numerical columns.
correlation_matrix = df.corr(numeric_only=True)

# Display the correlation values with the 'isFraud' column, sorted.
print(correlation_matrix['isFraud'].sort_values(ascending=False))
# Out:
# --- Correlation Analysis ---
# isFraud           1.000000
# step              0.806796
# amount            0.383737
# oldbalanceOrg     0.099037
# newbalanceDest    0.009942
# oldbalanceDest   -0.060313
# newbalanceOrig   -0.222409
# isFlaggedFraud         NaN
# Name: isFraud, dtype: float64

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['type'] = le.fit_transform(df['type'])
df['oldbalanceOrg'] = le.fit_transform(df['oldbalanceOrg'])
df['newbalanceOrig'] = le.fit_transform(df['newbalanceOrig'])

# %%
df
# Out:
#       step  type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0        1     3   9839.64  C1231006815           1172             700
# 1        1     3   1864.28  C1666544295            538             301
# 2        1     4    181.00  C1305486145             31               0
# 3        1     1    181.00   C840083671             31               0
# 4        1     3  11668.14  C2048537720            798             404
# ...    ...   ...       ...          ...            ...             ...
# 3137    95     1  56745.14   C526144262            890               0
# 3138    95     4  33676.59   C732111322            731               0
# 3139    95     1  33676.59  C1000086512            731               0
# 3140    95     4  87999.25   C927181710           1007               0
# 3141    95     1  87999.25   C409531429           1007               0
#
#          nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0     M1979787155            0.00            0.00        0               0
# 1     M2044282225            0.00            0.00        0               0
# 2      C553264065            0.00            0.00        1               0
# 3       C38997010        21182.00            0.00        1               0
# 4     M1230701703            0.00            0.00        0               0
# ...           ...             ...             ...      ...             ...
# 3137    C79051264        51433.88       108179.02        1               0
# 3138  C1140210295            0.00            0.00        1               0
# 3139  C1759363094            0.00        33676.59        1               0
# 3140   C757947873            0.00            0.00        1               0
# 3141  C1827219533            0.00        87999.25        1               0
#
# [3142 rows x 11 columns]
